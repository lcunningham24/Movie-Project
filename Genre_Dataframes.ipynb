# %%
import pandas as pd 
df = pd.read_csv('updated_dataframe.csv')
df
# Out:
#       Unnamed: 0  Unnamed: 0.1                                 Movie Title  \
# 0              0             0  Star Wars: Episode VII - The Force Awakens
# 1              1             1                           Avengers: Endgame
# 2              2             2                               Black Panther
# 3              3             3                      Avengers: Infinity War
# 4              4             4                              Jurassic World
# ...          ...           ...                                         ...
# 4101        4101          5240                                   Policeman
# 4102        4102          5241                                   Big Words
# 4103        4103          5242                           False Confessions
# 4104        4104          5243                                The Dry Land
# 4105        4105          5244                            Vision Portraits
#
# ...

# %%
df['Worldwide Box Office (USD)']= df['Worldwide Box Office (USD)'].apply(lambda x: x.strip('$'))
df['Domestic Box Office (USD)']=df['Gross Revenue (USD)'].apply(lambda x: x.strip('$'))
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                                 Movie Title  \
# 0           0             0  Star Wars: Episode VII - The Force Awakens
# 1           1             1                           Avengers: Endgame
# 2           2             2                               Black Panther
# 3           3             3                      Avengers: Infinity War
# 4           4             4                              Jurassic World
#
#   Gross Revenue (USD)                      Genre     tconst  Runtime (min)  \
# 0        $936,662,225  Action, Adventure, Sci-Fi  tt2488496          136.0
# 1        $858,373,000   Action, Adventure, Drama  tt4154796          181.0
# 2        $700,059,566  Action, Adventure, Sci-Fi  tt1825683          134.0
# 3        $678,815,482  Action, Adventure, Sci-Fi  tt4154756          149.0
# 4        $652,270,625  Action, Adventure, Sci-Fi  tt0369610          124.0
#
#    IMDB Rating Worldwide Box Office (USD) Worldwide Box Office  \
# ...

# %%
new_df = df.drop(columns=['Unnamed: 0','Unnamed: 0.1','Gross Revenue (USD)','Worldwide Box Office'])
new_df.head()
new_df.columns
# Out:
# Index(['Movie Title', 'Genre', 'tconst', 'Runtime (min)', 'IMDB Rating',
#        'Worldwide Box Office (USD)', 'Domestic Box Office (USD)'],
#       dtype='object')

# %%
type(new_df['Worldwide Box Office (USD)'][0])
# Out:
# str

# %%
new_df

# %%
def coerce_df_columns_to_numeric(df, column_list):
    df[column_list] = df[column_list].apply(pd.to_numeric, errors='coerce')

# %%
new_df['trial'] = new_df[a].apply(lambda x: x.split())
new_df.head()
new_df['trial'] = new_df['trial'].
for ele in new_df
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-4fb2923343c3> in <module>
#       1 new_df['trial'] = new_df['Worldwide Box Office (USD)'].apply(lambda x: x.split())
#       2 new_df.head()
# ----> 3 new_df['trial'] = new_df['trial'].apply(lambda x: int(x))
#       4 new_df.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-36-4fb2923343c3> in <lambda>(x)
#       1 new_df['trial'] = new_df['Worldwide Box Office (USD)'].apply(lambda x: x.split())
# ...

# %%
for i in range(len(new_df['Worldwide Box Office (USD)'])): # specifying 1 here will skip the first row
    new_df['Worldwide Box Office (USD)'] = [float(x) for x in new_df['Worldwide Box Office (USD)']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-1bbefe81c24f> in <module>
# ...

# %%
new_df = pd.merge()

# %%
budget_data = pd.read_csv('Budget_data.csv')
budget_data
# Out:
#       Unnamed: 0  adult                     backdrop_path  \
# 0              0  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# 1              1  False  /orjiB3oUIsyz60hoEqkiGpy5CeO.jpg
# 2              2  False  /6ELJEzQJ3Y45HczvreC3dg0GV5R.jpg
# 3              3  False  /lmZFxXgJE3vgrciwuDib0N8CfQo.jpg
# 4              4  False  /xX0IzuFa1Fj06iU2NlOmeMPe7oS.jpg
# ...          ...    ...                               ...
# 5240        5240  False                               NaN
# 5241        5241  False                               NaN
# 5242        5242  False                               NaN
# 5243        5243  False                               NaN
# 5244        5244  False                               NaN
#
#                                   belongs_to_collection       budget  \
# 0     {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000.0
# 1     {'id': 86311, 'name': 'The Avengers Collection...  356000000.0
# ...

# %%
budget_data['tconst'] = budget_data['imdb_id']
budget_data.columns
# Out:
# Index(['Unnamed: 0', 'adult', 'backdrop_path', 'belongs_to_collection',
#        'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'status_code', 'status_message',
#        'tconst'],
#       dtype='object')

# %%
budget_data['budget']=budget_data['budget'].replace(0,None)
budget_data.columns
# Out:
# Index(['Unnamed: 0', 'adult', 'backdrop_path', 'belongs_to_collection',
#        'budget', 'genres', 'homepage', 'id', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'status_code', 'status_message',
#        'tconst'],
#       dtype='object')

# %%
l = (new_df['Worldwide Box Office (USD)'])

# %%
l
# Out:
# 0       2,068,223,624
# 1       2,797,800,564
# 2       1,346,913,161
# 3       2,048,359,754
# 4       1,670,400,637
#             ...
# 4101           38,263
# 4102            8,965
# 4103           56,165
# 4104           11,777
# 4105           10,771
# Name: Worldwide Box Office (USD), Length: 4106, dtype: object

# %%
new_list = []
for ele in l: 
    new_list.append(ele.split())

# %%
new_list2 = []
for i in range(len(new_list)):
    new[list][i] = new_list2.append(int(ele))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-0fd7aed830fa> in <module>
#       1 new_list2 = []
#       2 for i in range(len(new_list)):
# ----> 3     new[list][i] = new_list2.append(int(ele))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
new_df['Worldwide Box Office (USD)'] = new_df['Worldwide Box Office (USD)'].str.replace(',','')
new_df['Worldwide Box Office (USD)'] = new_df['Worldwide Box Office (USD)'].astype(int)

# %%
new_df.head()
# Out:
#                                   Movie Title                      Genre  \
# 0  Star Wars: Episode VII - The Force Awakens  Action, Adventure, Sci-Fi
# 1                           Avengers: Endgame   Action, Adventure, Drama
# 2                               Black Panther  Action, Adventure, Sci-Fi
# 3                      Avengers: Infinity War  Action, Adventure, Sci-Fi
# 4                              Jurassic World  Action, Adventure, Sci-Fi
#
#       tconst  Runtime (min)  IMDB Rating  Worldwide Box Office (USD)  \
# 0  tt2488496          136.0          8.0                  2068223624
# 1  tt4154796          181.0          8.8                  2797800564
# 2  tt1825683          134.0          7.3                  1346913161
# 3  tt4154756          149.0          8.5                  2048359754
# 4  tt0369610          124.0          7.0                  1670400637
#
#   Domestic Box Office (USD)            trial
# 0               936,662,225  [2,068,223,624]
# ...

# %%
new_df.describe()
# Out:
#        Runtime (min)  IMDB Rating  Worldwide Box Office (USD)
# count    4078.000000  4106.000000                4.106000e+03
# mean      104.392104     6.464856                6.365885e+07
# std        19.394603     1.029989                1.722848e+08
# min        40.000000     1.500000                5.280000e+02
# 25%        91.000000     5.900000                1.617362e+05
# 50%       101.000000     6.600000                3.170573e+06
# 75%       114.000000     7.200000                4.102896e+07
# max       319.000000     9.400000                2.797801e+09

# %%
new_df['Domestic Box Office (USD)'] = new_df['Domestic Box Office (USD)'].str.replace(',','')
new_df['Domestic Box Office (USD)'] = new_df['Domestic Box Office (USD)'].astype(int)

# %%
new_df.head()
new_df.drop(columns=['trial'],inplace=True)

# %%
new_df
# Out:
#                                      Movie Title                      Genre  \
# 0     Star Wars: Episode VII - The Force Awakens  Action, Adventure, Sci-Fi
# 1                              Avengers: Endgame   Action, Adventure, Drama
# 2                                  Black Panther  Action, Adventure, Sci-Fi
# 3                         Avengers: Infinity War  Action, Adventure, Sci-Fi
# 4                                 Jurassic World  Action, Adventure, Sci-Fi
# ...                                          ...                        ...
# 4101                                   Policeman                Documentary
# 4102                                   Big Words              Comedy, Drama
# 4103                           False Confessions              Comedy, Drama
# 4104                                The Dry Land                      Drama
# 4105                            Vision Portraits                Documentary
#
# ...

# %%
df_combining = pd.merge(new_df,budget_data[['tconst','budget','release_date','popularity','revenue']],on='tconst')
df_combining
# Out:
#                                      Movie Title                      Genre  \
# 0     Star Wars: Episode VII - The Force Awakens  Action, Adventure, Sci-Fi
# 1                              Avengers: Endgame   Action, Adventure, Drama
# 2                                  Black Panther  Action, Adventure, Sci-Fi
# 3                         Avengers: Infinity War  Action, Adventure, Sci-Fi
# 4                                 Jurassic World  Action, Adventure, Sci-Fi
# ...                                          ...                        ...
# 4069                                   Policeman                Documentary
# 4070                                   Big Words              Comedy, Drama
# 4071                           False Confessions              Comedy, Drama
# 4072                                The Dry Land                      Drama
# 4073                            Vision Portraits                Documentary
#
# ...

# %%
df_combining['budget'] = df_combining['budget'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-be5058580ac0> in <module>
# ----> 1 df_combining['budget'] = df_combining['budget'].astype(int)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
df_combining.to_csv('new_merge_with_budget.csv')

# %%
df = pd.read_csv('new_merge_with_budget.csv')
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df_action = df[df['Genre'].str.contains('Action')]
df_action
# Out:
#                                      Movie Title                      Genre  \
# 0     Star Wars: Episode VII - The Force Awakens  Action, Adventure, Sci-Fi
# 1                              Avengers: Endgame   Action, Adventure, Drama
# 2                                  Black Panther  Action, Adventure, Sci-Fi
# 3                         Avengers: Infinity War  Action, Adventure, Sci-Fi
# 4                                 Jurassic World  Action, Adventure, Sci-Fi
# ...                                          ...                        ...
# 4039                                  Mr. Chibbs     Action, Drama, History
# 4049                                  Ghost Team      Short, Action, Comedy
# 4053                                  Casting By     Action, Drama, Western
# 4058                         Photographic Memory    Action, Comedy, History
# 4065                             The Lost Arcade   Action, Drama, Game-Show
#
# ...

# %%
l = list(x.split() for x in df['Genre'])

# %%
x = []
for item in l:
    for i in item:
        y = i.replace(',','')
        x.append(y)
x
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Action',
#  'Adventure',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Mystery',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Animation',
#  'Adventure',
#  'Comedy',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Adventure',
#  'Drama',
# ...

# %%
y = set(x)
y
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Short',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western'}

# %%
df_drama = df[df['Genre'].str.contains('Drama')]
df_drama
# Out:
#                                        Movie Title                      Genre  \
# 1                                Avengers: Endgame   Action, Adventure, Drama
# 23    Harry Potter and the Deathly Hallows: Part 2  Adventure, Drama, Fantasy
# 26                                 The Jungle Book   Adventure, Drama, Family
# 32                                 American Sniper   Action, Biography, Drama
# 36                                           Joker     Crime, Drama, Thriller
# ...                                            ...                        ...
# 4067               Brooklyn Brothers Beat the Best              Comedy, Drama
# 4068                                         Udaan              Comedy, Drama
# 4070                                     Big Words              Comedy, Drama
# 4071                             False Confessions              Comedy, Drama
# 4072                                  The Dry Land                      Drama
#
# ...

# %%
df_comedy = df[df['Genre'].str.contains('Comedy')]
df_comedy
# Out:
#                           Movie Title                         Genre  \
# 9                        Finding Dory  Animation, Adventure, Comedy
# 15                        Toy Story 3  Animation, Adventure, Comedy
# 19     Jumanji: Welcome to the Jungle     Action, Adventure, Comedy
# 20                             Frozen  Animation, Adventure, Comedy
# 21                             Frozen  Animation, Adventure, Comedy
# ...                               ...                           ...
# 4062                    Gringo Trails                 Comedy, Music
# 4067  Brooklyn Brothers Beat the Best                 Comedy, Drama
# 4068                            Udaan                 Comedy, Drama
# 4070                        Big Words                 Comedy, Drama
# 4071                False Confessions                 Comedy, Drama
#
#          tconst  Runtime (min)  IMDB Rating  Worldwide Box Office (USD)  \
# 9     tt2277860           97.0          7.3                  1028570889
# ...

# %%
df_documentary = df[df['Genre'].str.contains('Documentary')]
df_documentary
# Out:
#                          Movie Title                        Genre     tconst  \
# 235                       Jackass 3D  Documentary, Action, Comedy  tt1116184
# 405   Justin Bieber: Never Say Never           Documentary, Music  tt1702443
# 776            2016: Obama's America                  Documentary  tt2247692
# 792       Kevin Hart: Let Me Explain          Documentary, Comedy  tt2609912
# 844                       Chimpanzee          Documentary, Family  tt1222815
# ...                              ...                          ...        ...
# 4050            The Snowtown Murders       Documentary, Biography  tt1680114
# 4055       The Ballad of Lefty Brown                  Documentary  tt4400994
# 4057                      Dark River           Documentary, Drama  tt5700176
# 4069                       Policeman                  Documentary  tt1978447
# 4073                Vision Portraits                  Documentary  tt9617506
#
# ...

# %%
df_crime = df[df['Genre'].str.contains('Crime')]
df_crime
# Out:
#                                  Movie Title                     Genre  \
# 30                                 Furious 7  Action, Adventure, Crime
# 36                                     Joker    Crime, Drama, Thriller
# 37                                     Joker    Crime, Drama, Thriller
# 85                   The Fate of the Furious  Action, Adventure, Crime
# 97                                 Fast Five  Action, Adventure, Crime
# ...                                      ...                       ...
# 3985                            Silent Night    Crime, Drama, Thriller
# 4008                          Levitated Mass    Crime, Drama, Thriller
# 4016                                Cupcakes  Action, Adventure, Crime
# 4037  Trust Machine: The Story of Blockchain     Crime, Drama, Mystery
# 4046                              Dracula 3D   Biography, Crime, Drama
#
#          tconst  Runtime (min)  IMDB Rating  Worldwide Box Office (USD)  \
# ...

# %%
df_thriller = df[df['Genre'].str.contains('Thriller')]
df_thriller
# Out:
#                                             Movie Title  \
# 36                                                Joker
# 37                                                Joker
# 48                                              Skyfall
# 57                                              Gravity
# 87                        Mission: Impossible - Fallout
# ...                                                 ...
# 4004                                           The Eyes
# 4008                                     Levitated Mass
# 4028  Man on a Mission: Richard Garriott's Road to t...
# 4041                                             Spiral
# 4045                                           Starfish
#
#                             Genre     tconst  Runtime (min)  IMDB Rating  \
# 36         Crime, Drama, Thriller  tt1918886          104.0          2.6
# 37         Crime, Drama, Thriller  tt1918886          104.0          2.6
# ...

# %%
df_thriller[]
